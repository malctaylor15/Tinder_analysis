# %% [markdown]
# ## Begin looking into dataframe
#
# * Begin simple plots
# * Export plots into pdfs

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import json
import os 
import re

# %%
from importlib import reload

# %%
from Scripts import EDA_functions as mt_eda
reload(mt_eda)
# Out:
# <module 'Scripts.EDA_functions' from '/home/owner/Documents/Github_projects/Tinder_analysis/Scripts/EDA_functions.py'>

# %% [markdown]
# ### Import dataset from EDA v1

# %%
all_msg_df = pd.read_csv("Data/Checkpoint_messages.csv")

# %%
all_msg_df.set_index(["match_id", "msg_number"], inplace = True)

# %%
all_msg_df.dtypes
# Out:
# explicit_word_in_msg      float64
# fixed_height               object
# from                       object
# funny_word_in_msg         float64
# message                    object
# n_words_in_msg            float64
# question_mark_in_msg      float64
# question_word_in_msg      float64
# sent_date                  object
# time_since_last_2_msgs     object
# time_since_last_msg        object
# to                         object
# type                       object
# dtype: object

# %%
all_msg_df['sent_date'] = pd.to_datetime(all_msg_df['sent_date'])

# %%
all_texts = all_msg_df['message'].str.cat(sep=' ')

# %%
all_texts_list = all_texts.split(" ")

# %%
len(all_texts_list)
# Out:
# 10653

# %%
len(set(all_texts_list))
# Out:
# 2507

# %%
from collections import Counter

# %%
most_common_words = Counter(all_texts_list).most_common(30)

# %%
np.mean([len(x[0]) for x in most_common_words])
# Out:
# 2.9

# %% [markdown]
# ## Prep for plotting

# %%
all_msg_df['flatten_date'] = all_msg_df['sent_date'].apply(mt_eda.flatten_date)

# %%
all_msg_df_temp = all_msg_df.reset_index(level=['match_id', 'msg_number'])

# %%
dt_gb = all_msg_df_temp.groupby('flatten_date')

# %%
flag_col = ['explicit_word_in_msg', 'funny_word_in_msg', 'question_mark_in_msg', 'question_word_in_msg']

# %%
n_msg_over_time = dt_gb.apply(len)

# %%
plts = []
plts.append(mt_eda.plot_number_of_msgs_ovr_time(n_msg_over_time))
for demo_flg in flag_col:
    plts.append(mt_eda.plot_flag_fx(n_msg_over_time, dt_gb[demo_flg].sum(), demo_flg))

# %% [markdown]
# ## Create PDF of plots

# %%
from matplotlib.backends.backend_pdf import PdfPages

# %%
pp = PdfPages('foo.pdf')

# %%
for plt in plts:
    pp.savefig(plt)

# %%
pp.close()
